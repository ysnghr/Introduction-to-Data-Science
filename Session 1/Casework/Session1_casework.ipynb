# %% [markdown]
# ### Yasin Guliyev

# %% [markdown]
# # Session 1 case study

# %% [markdown]
# ### Import HR Data to Python.

# %% [markdown]
# ### Step1.Import the necessary libraries.

# %%
import pandas as pd
import statistics as st

# %% [markdown]
# ### Step 2. Call our Data as HR

# %%
data = pd.read_excel('HR Analytics.xlsx')

# %% [markdown]
# ### Step 3. See the first 5 entries, then 12 entries.

# %%
data.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.head(12)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# 5    32        No  Travel_Frequently       1005  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 7    30        No      Travel_Rarely       1358  Research & Development
# 8    38        No  Travel_Frequently        216  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 10   35        No      Travel_Rarely        809  Research & Development
# 11   29        No      Travel_Rarely        153  Research & Development
#
# ...

# %% [markdown]
# ### Step 4. See the last 2, then 9 entries.

# %%
data.tail(2)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 1468               2               9                  6
# ...

# %%
data.tail(9)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1461   50       Yes      Travel_Rarely        410                   Sales
# 1462   39        No      Travel_Rarely        722                   Sales
# 1463   31        No         Non-Travel        325  Research & Development
# 1464   26        No      Travel_Rarely       1167                   Sales
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1461                28          3      Marketing              1
# 1462                24          1      Marketing              1
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
data.shape
# Out:
# (1470, 35)

# %%
1470*35
# Out:
# 51450

# %% [markdown]
# ### Step 6.Groupby age and return the mean of the remaining columns in each group.

# %%
data.groupby('Age').mean()
# Out:
#       DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# Age
# 18   747.625000          6.125000   2.500000            1.0     1053.625000
# 19   548.444444         10.555556   2.111111            1.0      675.666667
# 20   819.454545          7.090909   2.636364            1.0     1021.000000
# 21   762.846154          9.076923   1.615385            1.0      951.538462
# 22   806.937500          8.437500   1.812500            1.0      869.250000
# 23   707.928571          9.142857   1.857143            1.0     1225.500000
# 24   863.115385         11.884615   2.115385            1.0     1011.384615
# 25   768.076923          8.769231   1.923077            1.0     1005.307692
# 26   844.769231         10.230769   2.641026            1.0      981.051282
# 27   907.333333          7.500000   2.666667            1.0     1001.958333
# 28   927.500000          8.875000   2.791667            1.0     1120.125000
# ...

# %% [markdown]
# ### Step7. Check if it has null values , then show sum of them

# %%
data.isnull()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ### Step 8. What is the mean of Hourly Rate?

# %%
data['HourlyRate'].mean()
# Out:
# 65.89115646258503

# %% [markdown]
# ### Step 9. What is max&min age of employees?

# %%
data['Age'].max()
# Out:
# 60

# %%
data['Age'].min()
# Out:
# 18

# %% [markdown]
# ### Step 10. What is the most frequent level of Education that  employees have?

# %%
data['Education'].mode()
# Out:
# 0    3
# dtype: int64

# %% [markdown]
# ### Step 11. What is median of total working years ?

# %%
data['TotalWorkingYears'].median()
# Out:
# 10.0

# %% [markdown]
# ### Step 12. Sort values by YearsatCompany in ascending order.

# %%
data.sort_values('YearsAtCompany', ascending = True)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1311   18        No         Non-Travel       1431  Research & Development
# 1371   56        No      Travel_Rarely       1443                   Sales
# 460    26        No      Travel_Rarely        775                   Sales
# 1068   28       Yes  Travel_Frequently        289  Research & Development
# 457    18       Yes  Travel_Frequently       1306                   Sales
# ...   ...       ...                ...        ...                     ...
# 561    52        No      Travel_Rarely        621                   Sales
# 1116   55        No      Travel_Rarely        685                   Sales
# 270    55        No      Travel_Rarely        452  Research & Development
# 98     58        No      Travel_Rarely        682                   Sales
# 126    58       Yes      Travel_Rarely        147  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ### Step 13. What is difference between max and min age of employees?

# %%
data['Age'].max()-data['Age'].min()
# Out:
# 42

# %% [markdown]
# ### Step 14. What is Standard deviation of the Age of Employees?

# %%
data['Age'].std()
# Out:
# 9.135373489136734

# %% [markdown]
# ### Step 15. Get a statistical summary of the data set.
# ### Give Interpretation for it

# %% [markdown]
# ### I selected the column which named as DailyRate
# ### In this column the mean is 802.4857142857143
# ### The mode is 0 and 691
# ### The median is 802.0
# ### The standart deviation of this column is 403.50909994352827

# %% [markdown]
# ### Step 16.Summarize only the DistanceFromHome.

# %%
data['DistanceFromHome'].describe()
# Out:
# count    1470.000000
# mean        9.192517
# std         8.106864
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %% [markdown]
# ### Step17.Check its info

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %% [markdown]
# ### Step 18.What is the most frequent level of education that employees have?

# %%
data['Education'].mode()
# Out:
# 0    3
# dtype: int64

# %% [markdown]
# ### Step19.Display our dataframe in which Education which are more than 3.00

# %%
data[data['Education'] > 3.00]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 3      33        No  Travel_Frequently       1392  Research & Development
# 15     29        No      Travel_Rarely       1389  Research & Development
# 18     53        No      Travel_Rarely       1219                   Sales
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 22     34        No      Travel_Rarely        419  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1455   40        No      Travel_Rarely       1322  Research & Development
# 1456   35        No  Travel_Frequently       1199  Research & Development
# 1457   40        No      Travel_Rarely       1194  Research & Development
# 1458   35        No      Travel_Rarely        287  Research & Development
# 1460   29        No      Travel_Rarely        468  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...
